# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()

# %%
dataset = pd.read_csv('50_Startups.csv')l
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
cat_attribs = ["State"]
num_attribs = ["R&D Spend", "Administration","Marketing Spend"]
pipeline = ColumnTransformer([("num", "passthrough", num_attribs),("cat", OneHotEncoder(), cat_attribs)])
X = pipeline.fit_transform(dataset)
y = dataset.iloc[:,4].values
X = X[:, :-1]

# %%
from pandas.plotting import scatter_matrix
attribs = ["R&D Spend", "Administration","Marketing Spend","State", "Profit"]
scatter_matrix(dataset[attribs], figsize=(12,10), color = 'red')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc4393e7a20>,
# ...
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state =0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
Accuracy = r2_score(y_test, regressor.predict(X_test))*100
print('Accuracy = ' + str(Accuracy) + '%')
# Out:
# Accuracy = 93.47068473294998%
